# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import plotly.express as px

# %%
link = 'https://valorinveste.globo.com/cotacoes/'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.92 Safari/537.36'}
data = requests.get(link, headers=headers,timeout=5).text
soup = BeautifulSoup(data,'html.parser')

# %%
#procurando uma tabela na página
#em html uma tabela é representada pela tag table
table = soup.find_all('table')[2]
dataframe = pd.DataFrame(columns=['Nome','Código','Última','Variação(%)','Fech. dia anteior(R$)'])

# %%
#obtendo todas as linhas da tabela
#em html uma linha da tabela é representada pela tag <tr>
for row in table.tbody.find_all('tr'):
    #Obtendo todas as colunas em cada linha
    columns = row.find_all('td') #html cada coluna é <td>
    if(columns != []):
        nome = columns[0].text.strip(' ')
        codigo = columns[1].text.strip(' ')
        ultima = columns[2].text.strip(' ')
        variacao = columns[3].text.strip(' ')
        fech_dia_anterior = columns[4].text.strip(' ')
        dataframe = pd.concat([dataframe,pd.DataFrame.from_records([{
            'Nome':nome,
            'Código':codigo,
            'Última':ultima,
            'Variação(%)':variacao,
            'Fech. dia anterior(R$)':fech_dia_anterior
            }])])

dataframe
# Out:
#                      Nome   Código   Última Variação(%) Fech. dia anteior(R$)  \
# 0         FII ABC IMOB CI   ABCP11    71,17     -0,74 %                   NaN
# 0          FII ALIANZA CI   ALZR11   111,01     -1,62 %                   NaN
# 0         FII BB PRGII CI   BBPO11    85,50      1,27 %                   NaN
# 0                 FII BTG   BCFF11    66,26      1,64 %                   NaN
# 0             FII BCIA CI   BCIA11    84,99      1,47 %                   NaN
# 0            FII BEES CRI   BCRI11    95,31     -0,62 %                   NaN
# 0         FII ABSOLUTO CI   BPFF11    64,18      0,27 %                   NaN
# 0          FII BC FUND CI   BRCR11    59,22      0,17 %                   NaN
# 0           FII BR REALTY   BZLI11    17,00     -0,06 %                   NaN
# 0         FII BB PROGR CI  BBFI11B  1977,69      0,49 %                   NaN
# 0            FII GEN SHOP   FIGS11    50,39      1,49 %                   NaN
# 0          FII INDL BR CI   FIIB11   467,15      1,36 %                   NaN
# 0     FII S F LIMA CI  ER   FLMA11   139,24      8,63 %                   NaN
# 0         FII GGRCOVEP CI   GGRC11   116,00      0,35 %                   NaN
# 0            FII HTOPFOF3   HFOF11    69,69      1,74 %                   NaN
# 0        FII CSHG SHOP CI   HGBS11   190,14      2,47 %                   NaN
# 0         FII CSHG CRI CI   HGCR11   102,15     -0,83 %                   NaN
# 0         FII CSHG LOG CI   HGLG11   164,50      0,73 %                   NaN
# 0        FII CSHG REAL CI   HGRE11   123,01     -2,32 %                   NaN
# 0  FII HOTEL MAXINVEST CI   HTMX11   111,55      1,96 %                   NaN
# 0       FII IRIDIUM CI ER   IRDM11    92,35      0,38 %                   NaN
# 0          FII JS REAL CI   JSRE11    73,00      1,98 %                   NaN
# 0            FII KINEA CI   KNCR11    98,69      0,33 %                   NaN
# 0          FII KINEA IPCI   KNIP11    91,95     -0,04 %                   NaN
# 0            FII KINEA CI   KNRI11   140,20     -0,55 %                   NaN
# 0            FII MALLS BP   MALL11   103,50      0,93 %                   NaN
# 0           FII MERITO CI   MFII11    93,48     -0,19 %                   NaN
# 0         FII MOGNO CI ER   MGFF11    58,92      3,28 %                   NaN
# 0         FII MAXI REN CI   MXRF11    10,09      0,20 %                   NaN
# 0       FII OURI JPPCI ER   OUJP11    98,90      0,65 %                   NaN
# 0         FII POLO CRI CI   PORD11    90,84      0,15 %                   NaN
#
#   Fech. dia anterior(R$)
# 0                  71,70
# 0                 112,84
# 0                  84,43
# 0                  65,19
# 0                  83,76
# 0                  95,90
# 0                  64,01
# 0                  59,12
# 0                  17,01
# 0                1968,00
# 0                  49,65
# 0                 460,86
# 0                 128,18
# 0                 115,60
# 0                  68,50
# 0                 185,55
# 0                 103,00
# 0                 163,30
# 0                 125,93
# 0                 109,41
# 0                  92,00
# 0                  71,58
# 0                  98,37
# 0                  91,99
# 0                 140,98
# 0                 102,55
# 0                  93,66
# 0                  57,05
# 0                  10,07
# 0                  98,26
# 0                  90,70

# %%
fundos = dataframe.set_index(dataframe['Código'])
fundos
# Out:
#                            Nome   Código   Última Variação(%)  \
# Código
# ABCP11          FII ABC IMOB CI   ABCP11    71,17     -0,74 %
# ALZR11           FII ALIANZA CI   ALZR11   111,01     -1,62 %
# BBPO11          FII BB PRGII CI   BBPO11    85,50      1,27 %
# BCFF11                  FII BTG   BCFF11    66,26      1,64 %
# BCIA11              FII BCIA CI   BCIA11    84,99      1,47 %
# BCRI11             FII BEES CRI   BCRI11    95,31     -0,62 %
# BPFF11          FII ABSOLUTO CI   BPFF11    64,18      0,27 %
# BRCR11           FII BC FUND CI   BRCR11    59,22      0,17 %
# BZLI11            FII BR REALTY   BZLI11    17,00     -0,06 %
# BBFI11B         FII BB PROGR CI  BBFI11B  1977,69      0,49 %
# FIGS11             FII GEN SHOP   FIGS11    50,39      1,49 %
# FIIB11           FII INDL BR CI   FIIB11   467,15      1,36 %
# FLMA11      FII S F LIMA CI  ER   FLMA11   139,24      8,63 %
# GGRC11          FII GGRCOVEP CI   GGRC11   116,00      0,35 %
# HFOF11             FII HTOPFOF3   HFOF11    69,69      1,74 %
# HGBS11         FII CSHG SHOP CI   HGBS11   190,14      2,47 %
# HGCR11          FII CSHG CRI CI   HGCR11   102,15     -0,83 %
# HGLG11          FII CSHG LOG CI   HGLG11   164,50      0,73 %
# HGRE11         FII CSHG REAL CI   HGRE11   123,01     -2,32 %
# HTMX11   FII HOTEL MAXINVEST CI   HTMX11   111,55      1,96 %
# IRDM11        FII IRIDIUM CI ER   IRDM11    92,35      0,38 %
# JSRE11           FII JS REAL CI   JSRE11    73,00      1,98 %
# KNCR11             FII KINEA CI   KNCR11    98,69      0,33 %
# KNIP11           FII KINEA IPCI   KNIP11    91,95     -0,04 %
# KNRI11             FII KINEA CI   KNRI11   140,20     -0,55 %
# MALL11             FII MALLS BP   MALL11   103,50      0,93 %
# MFII11            FII MERITO CI   MFII11    93,48     -0,19 %
# MGFF11          FII MOGNO CI ER   MGFF11    58,92      3,28 %
# MXRF11          FII MAXI REN CI   MXRF11    10,09      0,20 %
# OUJP11        FII OURI JPPCI ER   OUJP11    98,90      0,65 %
# PORD11          FII POLO CRI CI   PORD11    90,84      0,15 %
#
#         Fech. dia anteior(R$) Fech. dia anterior(R$)
# Código
# ABCP11                    NaN                  71,70
# ALZR11                    NaN                 112,84
# BBPO11                    NaN                  84,43
# BCFF11                    NaN                  65,19
# BCIA11                    NaN                  83,76
# BCRI11                    NaN                  95,90
# BPFF11                    NaN                  64,01
# BRCR11                    NaN                  59,12
# BZLI11                    NaN                  17,01
# BBFI11B                   NaN                1968,00
# FIGS11                    NaN                  49,65
# FIIB11                    NaN                 460,86
# FLMA11                    NaN                 128,18
# GGRC11                    NaN                 115,60
# HFOF11                    NaN                  68,50
# HGBS11                    NaN                 185,55
# HGCR11                    NaN                 103,00
# HGLG11                    NaN                 163,30
# HGRE11                    NaN                 125,93
# HTMX11                    NaN                 109,41
# IRDM11                    NaN                  92,00
# JSRE11                    NaN                  71,58
# KNCR11                    NaN                  98,37
# KNIP11                    NaN                  91,99
# KNRI11                    NaN                 140,98
# MALL11                    NaN                 102,55
# MFII11                    NaN                  93,66
# MGFF11                    NaN                  57,05
# MXRF11                    NaN                  10,07
# OUJP11                    NaN                  98,26
# PORD11                    NaN                  90,70

# %%
fundos.describe
# Out:
# <bound method NDFrame.describe of                            Nome   Código   Última Variação(%)  \
# Código
# ABCP11          FII ABC IMOB CI   ABCP11    71,17     -0,74 %
# ALZR11           FII ALIANZA CI   ALZR11   111,01     -1,62 %
# BBPO11          FII BB PRGII CI   BBPO11    85,50      1,27 %
# BCFF11                  FII BTG   BCFF11    66,26      1,64 %
# BCIA11              FII BCIA CI   BCIA11    84,99      1,47 %
# BCRI11             FII BEES CRI   BCRI11    95,31     -0,62 %
# BPFF11          FII ABSOLUTO CI   BPFF11    64,18      0,27 %
# BRCR11           FII BC FUND CI   BRCR11    59,22      0,17 %
# BZLI11            FII BR REALTY   BZLI11    17,00     -0,06 %
# BBFI11B         FII BB PROGR CI  BBFI11B  1977,69      0,49 %
# FIGS11             FII GEN SHOP   FIGS11    50,39      1,49 %
# FIIB11           FII INDL BR CI   FIIB11   467,15      1,36 %
# FLMA11      FII S F LIMA CI  ER   FLMA11   139,24      8,63 %
# GGRC11          FII GGRCOVEP CI   GGRC11   116,00      0,35 %
# HFOF11             FII HTOPFOF3   HFOF11    69,69      1,74 %
# HGBS11         FII CSHG SHOP CI   HGBS11   190,14      2,47 %
# HGCR11          FII CSHG CRI CI   HGCR11   102,15     -0,83 %
# HGLG11          FII CSHG LOG CI   HGLG11   164,50      0,73 %
# HGRE11         FII CSHG REAL CI   HGRE11   123,01     -2,32 %
# HTMX11   FII HOTEL MAXINVEST CI   HTMX11   111,55      1,96 %
# IRDM11        FII IRIDIUM CI ER   IRDM11    92,35      0,38 %
# JSRE11           FII JS REAL CI   JSRE11    73,00      1,98 %
# KNCR11             FII KINEA CI   KNCR11    98,69      0,33 %
# KNIP11           FII KINEA IPCI   KNIP11    91,95     -0,04 %
# KNRI11             FII KINEA CI   KNRI11   140,20     -0,55 %
# MALL11             FII MALLS BP   MALL11   103,50      0,93 %
# MFII11            FII MERITO CI   MFII11    93,48     -0,19 %
# MGFF11          FII MOGNO CI ER   MGFF11    58,92      3,28 %
# MXRF11          FII MAXI REN CI   MXRF11    10,09      0,20 %
# OUJP11        FII OURI JPPCI ER   OUJP11    98,90      0,65 %
# PORD11          FII POLO CRI CI   PORD11    90,84      0,15 %
#
#         Fech. dia anteior(R$) Fech. dia anterior(R$)
# Código
# ABCP11                    NaN                  71,70
# ALZR11                    NaN                 112,84
# BBPO11                    NaN                  84,43
# BCFF11                    NaN                  65,19
# BCIA11                    NaN                  83,76
# BCRI11                    NaN                  95,90
# BPFF11                    NaN                  64,01
# BRCR11                    NaN                  59,12
# BZLI11                    NaN                  17,01
# BBFI11B                   NaN                1968,00
# FIGS11                    NaN                  49,65
# FIIB11                    NaN                 460,86
# FLMA11                    NaN                 128,18
# GGRC11                    NaN                 115,60
# HFOF11                    NaN                  68,50
# HGBS11                    NaN                 185,55
# HGCR11                    NaN                 103,00
# HGLG11                    NaN                 163,30
# HGRE11                    NaN                 125,93
# HTMX11                    NaN                 109,41
# IRDM11                    NaN                  92,00
# JSRE11                    NaN                  71,58
# KNCR11                    NaN                  98,37
# KNIP11                    NaN                  91,99
# KNRI11                    NaN                 140,98
# MALL11                    NaN                 102,55
# MFII11                    NaN                  93,66
# MGFF11                    NaN                  57,05
# MXRF11                    NaN                  10,07
# OUJP11                    NaN                  98,26
# PORD11                    NaN                  90,70  >

# %%
fundos.info
# Out:
# <bound method DataFrame.info of                            Nome   Código   Última Variação(%)  \
# Código
# ABCP11          FII ABC IMOB CI   ABCP11    71,17     -0,74 %
# ALZR11           FII ALIANZA CI   ALZR11   111,01     -1,62 %
# BBPO11          FII BB PRGII CI   BBPO11    85,50      1,27 %
# BCFF11                  FII BTG   BCFF11    66,26      1,64 %
# BCIA11              FII BCIA CI   BCIA11    84,99      1,47 %
# BCRI11             FII BEES CRI   BCRI11    95,31     -0,62 %
# BPFF11          FII ABSOLUTO CI   BPFF11    64,18      0,27 %
# BRCR11           FII BC FUND CI   BRCR11    59,22      0,17 %
# BZLI11            FII BR REALTY   BZLI11    17,00     -0,06 %
# BBFI11B         FII BB PROGR CI  BBFI11B  1977,69      0,49 %
# FIGS11             FII GEN SHOP   FIGS11    50,39      1,49 %
# FIIB11           FII INDL BR CI   FIIB11   467,15      1,36 %
# FLMA11      FII S F LIMA CI  ER   FLMA11   139,24      8,63 %
# GGRC11          FII GGRCOVEP CI   GGRC11   116,00      0,35 %
# HFOF11             FII HTOPFOF3   HFOF11    69,69      1,74 %
# HGBS11         FII CSHG SHOP CI   HGBS11   190,14      2,47 %
# HGCR11          FII CSHG CRI CI   HGCR11   102,15     -0,83 %
# HGLG11          FII CSHG LOG CI   HGLG11   164,50      0,73 %
# HGRE11         FII CSHG REAL CI   HGRE11   123,01     -2,32 %
# HTMX11   FII HOTEL MAXINVEST CI   HTMX11   111,55      1,96 %
# IRDM11        FII IRIDIUM CI ER   IRDM11    92,35      0,38 %
# JSRE11           FII JS REAL CI   JSRE11    73,00      1,98 %
# KNCR11             FII KINEA CI   KNCR11    98,69      0,33 %
# KNIP11           FII KINEA IPCI   KNIP11    91,95     -0,04 %
# KNRI11             FII KINEA CI   KNRI11   140,20     -0,55 %
# MALL11             FII MALLS BP   MALL11   103,50      0,93 %
# MFII11            FII MERITO CI   MFII11    93,48     -0,19 %
# MGFF11          FII MOGNO CI ER   MGFF11    58,92      3,28 %
# MXRF11          FII MAXI REN CI   MXRF11    10,09      0,20 %
# OUJP11        FII OURI JPPCI ER   OUJP11    98,90      0,65 %
# PORD11          FII POLO CRI CI   PORD11    90,84      0,15 %
#
#         Fech. dia anteior(R$) Fech. dia anterior(R$)
# Código
# ABCP11                    NaN                  71,70
# ALZR11                    NaN                 112,84
# BBPO11                    NaN                  84,43
# BCFF11                    NaN                  65,19
# BCIA11                    NaN                  83,76
# BCRI11                    NaN                  95,90
# BPFF11                    NaN                  64,01
# BRCR11                    NaN                  59,12
# BZLI11                    NaN                  17,01
# BBFI11B                   NaN                1968,00
# FIGS11                    NaN                  49,65
# FIIB11                    NaN                 460,86
# FLMA11                    NaN                 128,18
# GGRC11                    NaN                 115,60
# HFOF11                    NaN                  68,50
# HGBS11                    NaN                 185,55
# HGCR11                    NaN                 103,00
# HGLG11                    NaN                 163,30
# HGRE11                    NaN                 125,93
# HTMX11                    NaN                 109,41
# IRDM11                    NaN                  92,00
# JSRE11                    NaN                  71,58
# KNCR11                    NaN                  98,37
# KNIP11                    NaN                  91,99
# KNRI11                    NaN                 140,98
# MALL11                    NaN                 102,55
# MFII11                    NaN                  93,66
# MGFF11                    NaN                  57,05
# MXRF11                    NaN                  10,07
# OUJP11                    NaN                  98,26
# PORD11                    NaN                  90,70  >

# %%
#ibovespa.loc[lambda ibovespa: ibovespa.index=='MXRF11']
lista_interesses = ['MXRF11','KNRI11','HGLG11','BCFF11','ALZR11']
interesses = pd.DataFrame()
interesses.index = fundos['Código'][lista_interesses]
interesses['Nome'] = fundos['Nome'][lista_interesses]
interesses['Última'] = fundos['Última'][lista_interesses]
interesses['Variação(%)'] = fundos['Variação(%)'][lista_interesses]
interesses['Fech. dia anterior(R$)'] = fundos['Fech. dia anterior(R$)'][lista_interesses]

interesses
# Out:
#                    Nome  Última Variação(%) Fech. dia anterior(R$)
# Código
# MXRF11  FII MAXI REN CI   10,09      0,20 %                  10,07
# KNRI11     FII KINEA CI  140,20     -0,55 %                 140,98
# HGLG11  FII CSHG LOG CI  164,50      0,73 %                 163,30
# BCFF11          FII BTG   66,26      1,64 %                  65,19
# ALZR11   FII ALIANZA CI  111,01     -1,62 %                 112,84
